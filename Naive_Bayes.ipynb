# %% [markdown]
# <a href="https://colab.research.google.com/github/navatharshini/News-Article-Categorization/blob/main/Naive_Bayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Loading the necessary libraries
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from sklearn.datasets import fetch_20newsgroups
data = fetch_20newsgroups()
data.target_names
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %%
# Defining all the categories
categories = ['alt.atheism', 'comp.graphics', 'comp.os.ms-windows.misc', 'comp.sys.ibm.pc.hardware',
'comp.sys.mac.hardware', 'comp.windows.x', 'misc.forsale', 'rec.autos', 'rec.motorcycles', 'rec.sport.baseball',
'rec.sport.hockey', 'sci.crypt', 'sci.electronics', 'sci.med', 'soc.religion.christian', 'talk.politics.guns',
'talk.politics.mideast', 'talk.politics.misc', 'talk.religion.misc']

# Training the data on these categories
train = fetch_20newsgroups(subset='train', categories=categories)

# Testing the data for these categories
test = fetch_20newsgroups(subset='test', categories=categories)

# %%
# Importing necessary packages
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline

# Creating a model based on Multinomial Naive Bayes
model = make_pipeline(TfidfVectorizer(), MultinomialNB())

# Training the model with the train data
model.fit(train.data, train.target)

# Creating labels for the test data
labels = model.predict(test.data)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB

# Create a pipeline with a TfidfVectorizer followed by a Naive Bayes classifier
model = make_pipeline(TfidfVectorizer(), MultinomialNB())

# Fit the model on training data
model.fit(train.data, train.target)

# Make predictions on test data
labels = model.predict(test.data)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB

# Create a pipeline with a TfidfVectorizer followed by a Naive Bayes classifier
model = make_pipeline(TfidfVectorizer(), MultinomialNB())

# Fit the model on training data
model.fit(train.data, train.target)

# Make predictions on test data
labels = model.predict(test.data)

# %%
# Predicting category on new data based on trained model
def predict_category(s, train=train, model=model):
    pred = model.predict([s])
    return train.target_names[pred[0]]

# %%
# List of sample input texts to test the model
sample_texts = [
    "The latest technology trends in AI and machine learning",
    "How to play basketball and improve your shooting skills",
    "The importance of understanding religious texts and beliefs",
    "Computing and programming in Python for data science",
    "The best car models of 2023 and what to look for in a new vehicle"
]

# Loop through each sample text and predict the category
for text in sample_texts:
    predicted_category = predict_category(text)
    print(f"Text: '{text}'")
    print(f"Predicted Category: {predicted_category}\n")
# Out:
# Text: 'The latest technology trends in AI and machine learning'
# Predicted Category: comp.os.ms-windows.misc
#
# Text: 'How to play basketball and improve your shooting skills'
# Predicted Category: rec.sport.hockey
#
# Text: 'The importance of understanding religious texts and beliefs'
# Predicted Category: soc.religion.christian
#
# Text: 'Computing and programming in Python for data science'
# Predicted Category: comp.graphics
#
# Text: 'The best car models of 2023 and what to look for in a new vehicle'
# Predicted Category: rec.autos
